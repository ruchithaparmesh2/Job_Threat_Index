# %%
import pandas as pd

# %%
df  = pd.read_csv('Dataset1.csv')

# %%
df.head()
# Out:
#               Job titiles AI Impact  Tasks  AI models  AI_Workload_Ratio  \
# 0  Communications Manager       98%    365       2546           0.143362
# 1          Data Collector       95%    299       2148           0.139199
# 2              Data Entry       95%    325       2278           0.142669
# 3              Mail Clerk       95%    193       1366           0.141288
# 4      Compliance Officer       92%    194       1369           0.141709
#
#                       Domain
# 0         Communication & PR
# 1                  Data & IT
# 2  Administrative & Clerical
# 3      Leadership & Strategy
# 4       Medical & Healthcare

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
domain = df['Domain']

# %%
len(domain)
# Out:
# 4706

# %%
new_domain  = set(domain)

# %%
len(new_domain)
# Out:
# 10

# %%
print(new_domain)
# Out:
# {'Data & IT', 'Administrative & Clerical', 'Construction', 'Hospitality', 'Medical & Healthcare', 'Leadership & Strategy', 'Communication & PR', 'Law Enforcement', 'Sales & Marketing', 'Supply Chain & Logistics'}

# %%
domains=[]
for i in new_domain:
    domains.append(i)

# %%
df.head()
# Out:
#               Job titiles AI Impact  Tasks  AI models  AI_Workload_Ratio  \
# 0  Communications Manager       98%    365       2546           0.143362
# 1          Data Collector       95%    299       2148           0.139199
# 2              Data Entry       95%    325       2278           0.142669
# 3              Mail Clerk       95%    193       1366           0.141288
# 4      Compliance Officer       92%    194       1369           0.141709
#
#                       Domain
# 0         Communication & PR
# 1                  Data & IT
# 2  Administrative & Clerical
# 3      Leadership & Strategy
# 4       Medical & Healthcare

# %%
df.head()
# Out:
#               Job titiles AI Impact  Tasks  AI models  AI_Workload_Ratio  \
# 0  Communications Manager       98%    365       2546           0.143362
# 1          Data Collector       95%    299       2148           0.139199
# 2              Data Entry       95%    325       2278           0.142669
# 3              Mail Clerk       95%    193       1366           0.141288
# 4      Compliance Officer       92%    194       1369           0.141709
#
#                       Domain
# 0         Communication & PR
# 1                  Data & IT
# 2  Administrative & Clerical
# 3      Leadership & Strategy
# 4       Medical & Healthcare

# %%
job=df['Job titiles']
jobtitles=[]
for i in job:
    jobtitles.append(i)
jobcode={}
j=1
for i in jobtitles:
    jobcode[i]=j
    j+=1
    
df['job_title_code']=df['Job titiles'].map(jobcode)

# %%
domaincode={}

# %%
j=1
for i in domains:
    domaincode[i]=j
    j+=1

# %%
df['Domain_Code']=df['Domain'].map(domaincode)

# %%
df.head()
# Out:
#               Job titiles AI Impact  Tasks  AI models  AI_Workload_Ratio  \
# 0  Communications Manager       98%    365       2546           0.143362
# 1          Data Collector       95%    299       2148           0.139199
# 2              Data Entry       95%    325       2278           0.142669
# 3              Mail Clerk       95%    193       1366           0.141288
# 4      Compliance Officer       92%    194       1369           0.141709
#
#                       Domain  job_title_code  Domain_Code
# 0         Communication & PR               1            7
# 1                  Data & IT               2            1
# 2  Administrative & Clerical               3            2
# 3      Leadership & Strategy               4            6
# 4       Medical & Healthcare               5            5

# %%
df = df.drop('Domain',axis=1)

# %%
df.head()
# Out:
#               Job titiles AI Impact  Tasks  AI models  AI_Workload_Ratio  \
# 0  Communications Manager       98%    365       2546           0.143362
# 1          Data Collector       95%    299       2148           0.139199
# 2              Data Entry       95%    325       2278           0.142669
# 3              Mail Clerk       95%    193       1366           0.141288
# 4      Compliance Officer       92%    194       1369           0.141709
#
#    job_title_code  Domain_Code
# 0               1            7
# 1               2            1
# 2               3            2
# 3               4            6
# 4               5            5

# %%
import seaborn as sns

# %%
sns.jointplot(x='AI Impact',y='Domain_Code',data=df)

# %%
sns.jointplot(x='Domain_Code',y='AI models',kind='hex',data=df)

# %%
sns.pairplot(df)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.boxplot(x='Tasks',data=df)
# Out:
# <AxesSubplot:xlabel='Tasks'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.boxplot(x='AI models',data=df)
# Out:
# <AxesSubplot:xlabel='AI models'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.boxplot(x='AI_Workload_Ratio',data=df)
# Out:
# <AxesSubplot:xlabel='AI_Workload_Ratio'>

# %%
import numpy as np

# %%
percentile25=df['Tasks'].quantile(0.25)
percentile75=df['Tasks'].quantile(0.75)
iqr=percentile75-percentile25
upperlimitpm1=percentile75+1.5*iqr
lowerlimitpm1=percentile25-1.5*iqr
df['Tasks']=np.where(df['Tasks']>upperlimitpm1,upperlimitpm1,np.where(df['Tasks']<lowerlimitpm1,lowerlimitpm1,df['Tasks']))

# %%
sns.boxplot(x='Tasks',data=df)
plt.show()

# %%
sns.boxplot(x='AI_Workload_Ratio',data=df)
plt.show()

# %%
percentile25=df['AI models'].quantile(0.25)
percentile75=df['AI models'].quantile(0.75)
iqr=percentile75-percentile25
upperlimitpm1=percentile75+1.5*iqr
lowerlimitpm1=percentile25-1.5*iqr
df['AI models']=np.where(df['AI models']>upperlimitpm1,upperlimitpm1,np.where(df['AI models']<lowerlimitpm1,lowerlimitpm1,df['AI models']))

# %%
df.head()
# Out:
#               Job titiles AI Impact  Tasks  AI models  AI_Workload_Ratio  \
# 0  Communications Manager       98%  365.0     2546.0           0.143362
# 1          Data Collector       95%  299.0     2148.0           0.139199
# 2              Data Entry       95%  325.0     2278.0           0.142669
# 3              Mail Clerk       95%  193.0     1366.0           0.141288
# 4      Compliance Officer       92%  194.0     1369.0           0.141709
#
#    job_title_code  Domain_Code
# 0               1            7
# 1               2            1
# 2               3            2
# 3               4            6
# 4               5            5

# %%
df=df.drop('Job titiles',axis=1)

# %%
for i in range(len(df['AI Impact'])):
    s=df['AI Impact'][i]
    n=len(s)
    a=s[0:n-1]
    a=int(a)
    df['AI Impact'][i]=a
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_27560\2618703470.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['AI Impact'][i]=a

# %%
for i in range(len(df['AI_Workload_Ratio'])):
    a=df['AI_Workload_Ratio'][i]
    b=round(a,2)
    df['AI_Workload_Ratio'][i]=b
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_27560\4022844787.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['AI_Workload_Ratio'][i]=b

# %%
import numpy as np

# Check for NaN values
nan_indices = np.isnan(df['AI_Workload_Ratio'])

# Check for infinite values
inf_indices = np.isinf(df['AI_Workload_Ratio'])

# Print the indices where NaN or infinite values are present
print("NaN indices:", np.where(nan_indices))
print("Infinite indices:", np.where(inf_indices))
# Out:
# NaN indices: (array([], dtype=int64),)
# Infinite indices: (array([3034, 3035, 3036, 3037, 3184, 3211, 3322], dtype=int64),)

# %%
df.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
import numpy as np

# Check for NaN values
nan_indices = np.isnan(df['Tasks'])

# Check for infinite values
inf_indices = np.isinf(df['Tasks'])

# Print the indices where NaN or infinite values are present
print("NaN indices:", np.where(nan_indices))
print("Infinite indices:", np.where(inf_indices))
# Out:
# NaN indices: (array([], dtype=int64),)
# Infinite indices: (array([], dtype=int64),)

# %%
df=df.dropna()

# %%
df.head()
# Out:
#    AI Impact  Tasks  AI models  AI_Workload_Ratio  job_title_code  Domain_Code
# 0         98  365.0     2546.0               0.14               1            7
# 1         95  299.0     2148.0               0.14               2            1
# 2         95  325.0     2278.0               0.14               3            2
# 3         95  193.0     1366.0               0.14               4            6
# 4         92  194.0     1369.0               0.14               5            5

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop('AI Impact',axis=1), 
                                                    df['AI Impact'], test_size=0.30)

# %%
##KNN Regressor

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knn = KNeighborsRegressor(n_neighbors=120)

# %%
knn.fit(X_train.values,y_train.values)
# Out:
# KNeighborsRegressor(n_neighbors=120)

# %%
y_pred = knn.predict(X_test.values)

# %%
print(y_pred)
# Out:
# [31.40833333 48.95833333 20.08333333 ... 63.48333333 30.11666667
#  28.83333333]

# %%
from sklearn.metrics import r2_score

r2=r2_score(y_test,y_pred)
print(r2)
# Out:
# 0.9747451899880862

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, y_pred)
print(mae)
# Out:
# 1.6418735224586292

# %%
mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
print(mape)
# Out:
# 8.0708296228387

# %%
##SVR MODEL

# %%
from sklearn.svm import SVR

# %%
svr_model = SVR(kernel='rbf', C=1.0, epsilon=0.2)

# %%
svr_model.fit(X_train, y_train)
# Out:
# SVR(epsilon=0.2)

# %%
y_preds = svr_model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, y_preds)
print(mae)
# Out:
# 1.7820043481171046

# %%
from sklearn.metrics import mean_squared_error

# %%
mse = mean_squared_error(y_test, y_pred)

# %%
mse
# Out:
# 8.091710549645391

# %%
from sklearn.metrics import r2_score

r2=r2_score(y_test,y_preds)
print(r2)
# Out:
# 0.966888080433404

# %%
## RIDGE REGRESSION

# %%
from sklearn.linear_model import Ridge

# %%
alpha = 1.0  # Regularization strength (adjust as needed)
ridge_model = Ridge(alpha=alpha)

# %%
ridge_model.fit(X_train, y_train)
# Out:
# Ridge()

# %%
y_predr = ridge_model.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_predr)
print(f'Mean Squared Error: {mse}')
# Out:
# Mean Squared Error: 26.92526383343053

# %%
from sklearn.metrics import r2_score

r2=r2_score(y_test,y_predr)
print(r2)
# Out:
# 0.9159643170054149

# %%
##XGBOOST

# %%
import xgboost as xgb

# %%
xg_reg = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=0.3, learning_rate=0.1,
                          max_depth=5, alpha=10, n_estimators=200)

# %%
xg_reg.fit(X_train, y_train)
# Out:
# XGBRegressor(alpha=10, base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.3, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=200, n_jobs=None, num_parallel_tree=None,
#              predictor=None, ...)

# %%
y_predx = xg_reg.predict(X_test)

# %%
from sklearn.metrics import r2_score

r2=r2_score(y_test,y_predx)
print(r2)
# Out:
# 0.9803316082226164

# %%
mse = mean_squared_error(y_test, y_predx)
print(f'Mean Squared Error: {mse}')
# Out:
# Mean Squared Error: 6.301806791044382

# %%
##Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf_reg = RandomForestRegressor(n_estimators=300, random_state=20)

# %%
rf_reg.fit(X_train, y_train.ravel())
# Out:
# RandomForestRegressor(n_estimators=300, random_state=20)

# %%
y_predf = rf_reg.predict(X_test)

# %%
from sklearn.metrics import r2_score

r2=r2_score(y_test,y_predf)
print(r2)
# Out:
# 0.9999151880083148

# %%
import pickle

filename = "secondimp.pkl"

pickle.dump(rf_reg,open(filename,'wb'))

rf_reg1=pickle.load(open('secondimp.pkl','rb'))

print(rf_reg1.predict([[365,2546,0.14,1,7]]))
# Out:
# [94.37333333]
# C:\Users\hp\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
